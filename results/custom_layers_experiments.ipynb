# %% [markdown]
# # Результаты третьего задания

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'utils'))
import custom_layers_experiments

# %% [markdown]
# # Кастомные слои

# %% [markdown]
# # Сравнение модели с кастомными слоями с моделью со стандартными слоями
#
# - модель со стандартными слоями достига лучшей Test Accuracy
# - потери были более стабильными у модели с кастомными слоями

# %%
custom_layers_experiments.plot_custom_vs_baseline()

# %% [markdown]
# # Эксперименты с Residual блоками

# %% [markdown]
# # Сравнение производительности моделей с Residual блоками
#
# - Тest Accuracy у всех моделей примерно одинаковы

# %%
custom_layers_experiments.plot_test_accuracy_by_epoch()

# %% [markdown]
# # Анализ количества параметров
#
# - Значительно больше параметров у модели WideBlock, в сравнении с остальными
# - количество параметров у моделей DasicBlock и BottleneckBlock отличается не сильно

# %%
custom_layers_experiments.plot_parameters_comparison()

# %% [markdown]
# # Анализ стабильности обучения
#
# - WideBlock имеет заметно большее переобучение в сравнении с остальными моделями
# - WideBlock имеет самый нестабильный Test Loss среди всех прочих моделей

# %%
custom_layers_experiments.plot_training_stability()
