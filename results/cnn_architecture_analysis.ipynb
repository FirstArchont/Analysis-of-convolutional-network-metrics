# %% [markdown]
# # Результаты второго задания

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'utils'))
import cnn_architecture_analysis

# %% [markdown]
# # Влияние размера ядра свертки

# %% [markdown]
# # Сравнение Test Accuracy и времени обучения по размерам ядер свёртки
#
# - Test Accuracy выше всего у той модели, что имеет наименьшее по размеру ядро свёртки, так же она обучалась быстрее остальных
# - Большое едро свёртки заметно сократило Test Accuracy

# %%
cnn_architecture_analysis.plot_accuracy_vs_training_time()

# %% [markdown]
# # Анализ рецептивных полей
#
# - увеличение рецептивного поля не гарантирует увеличение точности
# - маленькое рецептивное поле ведёт к переобучению, что заметно на модели с маленьим ядром свёртки

# %%
cnn_architecture_analysis.plot_receptive_field_analysis()

# %% [markdown]
# # Активации первого слоя

# %% [markdown]
# ![alt text](<../plots/№2/1x1_3x3 модель активация первого слоя.png>)

# %% [markdown]
# ![alt text](<../plots/№2/3x3 модель активация первого слоя.png>)

# %% [markdown]
# ![alt text](<../plots/№2/5x5 модель активация первого слоя.png>)

# %% [markdown]
# ![alt text](<../plots/№2/7x7 модель активация первого слоя.png>)

# %% [markdown]
# # Влияние глубины CNN

# %% [markdown]
# # Сравнение точности и времени обучения
#
# - лучший Test Accuracy с большим отрывом у модели с большим количеством свёрточных слоёв, но обучается она не намного дольше прочих моделей
# - ResidualCNN обучалась очень долго, в сравнении с остальными моделями

# %%
cnn_architecture_analysis.plot_test_accuracy_and_training_time_bar()

# %% [markdown]
# # Анализ vanishing/exploding gradients
#
# - модели без Residual связей страдали от затухающих градиентов
# - Residual связи помогают держать градиенты от затухания или взрывания

# %%
cnn_architecture_analysis.vanishing_exploding_gradients()

# %% [markdown]
# # Анализ эффективности Residual связей
#
# - модель с Residual свзязями обучались быстрее остальных моделей до 5 эпохи
# - Residual свзязи лучше всех запоминают тестовые данные

# %%
cnn_architecture_analysis.plot_residual_effectiveness()

# %% [markdown]
# # Feature Maps

# %%
cnn_architecture_analysis.visualize_feature_maps_from_models()
