# %% [markdown]
# # Результаты первого задания

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'utils'))
import cnn_vs_fc_comparison

# %% [markdown]
# # Сравнение на MNIST

# %% [markdown]
# # Сравнение точности на Train и Test по моделям
#
# - у ResidualCNN Train и Test Accuracy больше всех
# - у полносвязной сети Train и Test Accuracy заметно меньше чем у свёрточных сетей

# %%
cnn_vs_fc_comparison.plot_final_accuracies_comparison()

# %% [markdown]
# # Сравнение времени обучения и времени инференса
#
# - ResidualCNN обучался заметно дольше остальных моделей
# - ResidualCNN медленней остальных сетей предсказывает классы

# %%
cnn_vs_fc_comparison.plot_training_inference_comparison()

# %% [markdown]
# # Кривые обучения

# %% [markdown]
# Полносвязная модель MNIST
# ![alt text](<../plots/№1/Полносвязная модель MNIST.png>)

# %% [markdown]
# Simple CNN MNIST
# ![alt text](<../plots/№1/простой CNN модель MNIST.png>)

# %% [markdown]
# Resdidual CNN MNIST
# ![alt text](<../plots/№1/Resdidual CNN модель MNIST.png>)

# %% [markdown]
# # Сравнение количества параметров моделей
#
# - у полносвязной сети параметров значительно больше остальных моделей
# - у DesidualCNN сравнительно с остальными моделями параметров не много

# %%
cnn_vs_fc_comparison.plot_parameters_comparison()

# %% [markdown]
# # Сравнение на CIFAR

# %% [markdown]
# # Сравнение точности и времени обучения
#
# - Выше всего Test Accuracy у ResidualCNN
# - у полносвязной сети Test Accuracy разительно нижк остальных моделей, но и обучается она значительно быстрее

# %%
cnn_vs_fc_comparison.plot_accuracy_vs_training_time_barchart()

# %% [markdown]
# # Анализ переобучения
#
# - у ResidualCNN ярко выраденное переобучение, разница точностей и потерь очень большая
# - у RegularizedResidualCNN переобучение умеренное
# - у полносвзяной сети переобучение не наблюдается

# %%
cnn_vs_fc_comparison.plot_overfitting_analysis()

# %% [markdown]
# # Сonfusion matrix
#
# - полносвязанная модель в 3 раза чаще видит в кошке собаку, чем кошку

# %%
cnn_vs_fc_comparison.plot_confusion_matrices()

# %% [markdown]
# # Исследование градиентов
#
# - у полносвязанной модели нормы градиентов болтаются больше всего
# - у свёрточных моделей нормы градиентов схожи

# %%
cnn_vs_fc_comparison.plot_gradient_norms()
